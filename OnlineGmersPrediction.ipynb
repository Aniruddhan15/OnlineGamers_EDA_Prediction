# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/online_gaming_behavior_dataset.csv')

# %%
df.head(10)
# Out:
#    PlayerID  Age  Gender Location   GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other    Strategy      16.271119                0
# 1      9001   29  Female      USA    Strategy       5.525961                0
# 2      9002   22  Female      USA      Sports       8.223755                0
# 3      9003   35    Male      USA      Action       5.265351                1
# 4      9004   33    Male   Europe      Action      15.531945                0
# 5      9005   37    Male   Europe         RPG      20.561855                0
# 6      9006   25    Male      USA      Action       9.752716                0
# 7      9007   25  Female     Asia         RPG       4.401729                0
# 8      9008   38  Female   Europe  Simulation      18.152733                0
# 9      9009   38  Female    Other      Sports      23.942772                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# ...

# %%
df.drop('PlayerID',axis=1,inplace=True)

# %%
df.shape
# Out:
# (40034, 12)

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Location                     0
# GameGenre                    0
# PlayTimeHours                0
# InGamePurchases              0
# GameDifficulty               0
# SessionsPerWeek              0
# AvgSessionDurationMinutes    0
# PlayerLevel                  0
# AchievementsUnlocked         0
# EngagementLevel              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 Age  PlayTimeHours  InGamePurchases  SessionsPerWeek  \
# count  40034.000000   40034.000000     40034.000000     40034.000000
# mean      31.992531      12.024365         0.200854         9.471774
# std       10.043227       6.914638         0.400644         5.763667
# min       15.000000       0.000115         0.000000         0.000000
# 25%       23.000000       6.067501         0.000000         4.000000
# 50%       32.000000      12.008002         0.000000         9.000000
# 75%       41.000000      17.963831         0.000000        14.000000
# max       49.000000      23.999592         1.000000        19.000000
#
#        AvgSessionDurationMinutes   PlayerLevel  AchievementsUnlocked
# count               40034.000000  40034.000000          40034.000000
# mean                   94.792252     49.655568             24.526477
# std                    49.011375     28.588379             14.430726
# min                    10.000000      1.000000              0.000000
# ...

# %%
df.EngagementLevel.value_counts()
# Out:
# EngagementLevel
# Medium    19374
# High      10336
# Low       10324
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['EngagementLevel'] = le.fit_transform(df['EngagementLevel'])
df['GameDifficulty'] = le.fit_transform(df['GameDifficulty'])
df['Gender'] = le.fit_transform(df['Gender'])
df['Location'] = le.fit_transform(df['Location'])
df['GameGenre'] = le.fit_transform(df['GameGenre'])
df['GameDifficulty'] = le.fit_transform(df['GameDifficulty'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        40034 non-null  int64
#  1   Gender                     40034 non-null  int64
#  2   Location                   40034 non-null  int64
#  3   GameGenre                  40034 non-null  int64
#  4   PlayTimeHours              40034 non-null  float64
#  5   InGamePurchases            40034 non-null  int64
#  6   GameDifficulty             40034 non-null  int64
#  7   SessionsPerWeek            40034 non-null  int64
#  8   AvgSessionDurationMinutes  40034 non-null  int64
#  9   PlayerLevel                40034 non-null  int64
#  10  AchievementsUnlocked       40034 non-null  int64
#  11  EngagementLevel            40034 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 3.7 MB

# %%
plt.figure(figsize=(12,12))
sns.boxplot(df)
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        40034 non-null  int64
#  1   Gender                     40034 non-null  int64
#  2   Location                   40034 non-null  int64
#  3   GameGenre                  40034 non-null  int64
#  4   PlayTimeHours              40034 non-null  float64
#  5   InGamePurchases            40034 non-null  int64
#  6   GameDifficulty             40034 non-null  int64
#  7   SessionsPerWeek            40034 non-null  int64
#  8   AvgSessionDurationMinutes  40034 non-null  int64
#  9   PlayerLevel                40034 non-null  int64
#  10  AchievementsUnlocked       40034 non-null  int64
#  11  EngagementLevel            40034 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 3.7 MB

# %%
sns.violinplot(x='Gender',y='SessionsPerWeek',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='SessionsPerWeek'>

# %%
sns.violinplot(x='Gender',y='PlayTimeHours',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='PlayTimeHours'>

# %%
sns.violinplot(x='Gender',y='AvgSessionDurationMinutes',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='AvgSessionDurationMinutes'>

# %%
sns.violinplot(x='Gender',y='InGamePurchases',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='InGamePurchases'>

# %%
sns.violinplot(x='EngagementLevel',y='AvgSessionDurationMinutes',data=df)
# Out:
# <Axes: xlabel='EngagementLevel', ylabel='AvgSessionDurationMinutes'>

# %%
sns.scatterplot(x='Age',y='EngagementLevel',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='EngagementLevel'>

# %%
sns.scatterplot(x='Age',y='PlayTimeHours',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='PlayTimeHours'>

# %%
sns.scatterplot(x='SessionsPerWeek',y='PlayTimeHours',data=df)
# Out:
# <Axes: xlabel='SessionsPerWeek', ylabel='PlayTimeHours'>

# %%
sns.scatterplot(x='PlayTimeHours',y='SessionsPerWeek',data=df)
# Out:
# <Axes: xlabel='PlayTimeHours', ylabel='SessionsPerWeek'>

# %%
plt.pie(df['InGamePurchases'].value_counts(),labels=df['InGamePurchases'].unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(df['Location'].value_counts(),labels=df['Location'].unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(df['EngagementLevel'].value_counts(),labels=df['EngagementLevel'].unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(13,10))
plt.pie(df['Age'].value_counts(),labels=df['Age'].unique(),autopct='%1.1f%%')
plt.show()

# %%
sns.histplot(x='GameGenre',hue='Age',data=df)
# Out:
# <Axes: xlabel='GameGenre', ylabel='Count'>

# %%
sns.histplot(x='SessionsPerWeek',hue='Age',data=df)
# Out:
# <Axes: xlabel='SessionsPerWeek', ylabel='Count'>

# %%
sns.histplot(x='EngagementLevel',hue='Location',data=df)
# Out:
# <Axes: xlabel='EngagementLevel', ylabel='Count'>

# %%
sns.barplot(x='EngagementLevel',y='Age',data=df)
# Out:
# <Axes: xlabel='EngagementLevel', ylabel='Age'>

# %%
sns.histplot(x='Age',data=df,hue='EngagementLevel')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.barplot(x='EngagementLevel',y='PlayTimeHours',data=df)
# Out:
# <Axes: xlabel='EngagementLevel', ylabel='PlayTimeHours'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=False,cmap='coolwarm',fmt='.2f',linewidths=1.5,linecolor='black',square=True)
plt.show()

# %%
X = df.drop('EngagementLevel',axis=1)
y = df['EngagementLevel']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
# !pip install --upgrade scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 42.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
from sklearn.linear_model import RidgeClassifier
ridge = RidgeClassifier()
ridge.fit(X_train, y_train)
# Out:
# RidgeClassifier()

# %%
y_pred = ridge.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8104705764811669

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      2623
#            1       0.82      0.69      0.75      2606
#            2       0.79      0.87      0.83      4780
#
#     accuracy                           0.81     10009
#    macro avg       0.82      0.79      0.80     10009
# weighted avg       0.81      0.81      0.81     10009

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[2165   79  379]
#  [  83 1795  728]
#  [ 320  308 4152]]

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3 = dt.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred3))
# Out:
# 0.8348486362273954

# %%
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82      2623
#            1       0.80      0.80      0.80      2606
#            2       0.86      0.86      0.86      4780
#
#     accuracy                           0.83     10009
#    macro avg       0.83      0.83      0.83     10009
# weighted avg       0.83      0.83      0.83     10009

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred4 = ada.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred4))
# Out:
# 0.7946847836946748

# %%
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80      2623
#            1       0.83      0.65      0.73      2606
#            2       0.75      0.91      0.82      4780
#
#     accuracy                           0.79     10009
#    macro avg       0.82      0.76      0.78     10009
# weighted avg       0.81      0.79      0.79     10009

# %%
print(confusion_matrix(y_test,y_pred4))
# Out:
# [[1909   75  639]
#  [  67 1706  833]
#  [ 165  276 4339]]

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
hgb = HistGradientBoostingClassifier()
hgb.fit(X_train,y_train)
# Out:
# HistGradientBoostingClassifier()

# %%
y_pred5 = hgb.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred5))
# Out:
# 0.9127784993505845

# %%
print(classification_report(y_test,y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      2623
#            1       0.91      0.88      0.90      2606
#            2       0.91      0.94      0.93      4780
#
#     accuracy                           0.91     10009
#    macro avg       0.91      0.90      0.91     10009
# weighted avg       0.91      0.91      0.91     10009

# %%
print(confusion_matrix(y_test,y_pred5))
# Out:
# [[2321   84  218]
#  [  76 2299  231]
#  [ 120  144 4516]]

# %%
df.head()
# Out:
#    Age  Gender  Location  GameGenre  PlayTimeHours  InGamePurchases  \
# 0   43       1         2          4      16.271119                0
# 1   29       0         3          4       5.525961                0
# 2   22       0         3          3       8.223755                0
# 3   35       1         3          0       5.265351                1
# 4   33       1         1          0      15.531945                0
#
#    GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0               2                6                        108           79
# 1               2                5                        144           11
# 2               0               16                        142           35
# 3               0                9                         85           57
# 4               2                2                        131           95
#
#    AchievementsUnlocked  EngagementLevel
# 0                    25                2
# ...

# %%
input_data = (43,1,2,4,16.271119,0,2,6,108,79,25)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = hgb.predict(input_data_reshaped)
print(prediction)
if (prediction[0] == 0):
  print('Low Engagement')
elif (prediction[0] == 1):
  print('Medium Engagement')
else:
  print('High Engagement')
# Out:
# [2]
# High Engagement

# %%
input_data = (22,0,3,3,8.223755,0,0,16,142,35,41)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = hgb.predict(input_data_reshaped)
print(prediction)
if (prediction[0] == 0):
  print('Low Engagement')
elif (prediction[0] == 1):
  print('Medium Engagement')
else:
  print('High Engagement')
# Out:
# [0]
# Low Engagement

# %%
import pickle

# %%
pickle.dump(hgb,open('hgb.pkl','wb'))

# %%
pickle.dump(dt,open('dt.pkl','wb'))

# %%
pickle.dump(ridge,open('ridge.pkl','wb'))

# %%
pickle.dump(ada,open('ada.pkl','wb'))
